# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x= np.array([1,2,3,4])
y= np.array([2,2.8,3.6,4.5])

# %%
# Out:
# array([1, 2, 3, 4])

# %%
y
# Out:
# array([2. , 2.8, 3.6, 4.5])

# %%
w = 0
b = 0
alpha = 0.01
num_iteration = 20

# %%
sse_values = []

#Gradient descent

for i in range(num_iteration):
    
    y_hat = w*x + b 
    
    D_w = 2 * np.sum((y_hat -y)*x)####gradient of w 
    D_b = 2 * np.sum(y_hat-y)### gradient of  b 
    
    #Update parameters
    w -= alpha * D_w
    b -= alpha * D_b
    
    #compute sse and store it on sse variable
    sse = (np.sum((y_hat -y)**2))
    sse_values.append(sse)
    
    if (i+1)  % 20 == 0 :
        print(f"iteration {i+1}, SSE: {sse}")
# Out:
# iteration 20, SSE: 0.025970433458555577

# %%
print(f"Optimized parameters: bais = {b}, slop = {w}")
# Out:
# Optimized parameters: bais = 0.9667904836077431, slop = 0.892313577366675

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(range(num_iteration),sse_values,label='sse')
plt.xlabel("Iteration")
plt.ylabel('SSE')
plt.title('SEE over iteration')
plt.legend()
# plt.show()

plt.subplot(1,2,2)
plt.scatter(x,y,color="blue",label='Data Points')
plt.plot(x, b+w*x, color = 'red', label='Regression Line')
plt.xlabel("X")
plt.ylabel('Y')
plt.title("Linear Regression Fit line")
plt.legend()
plt.show()

# %%
y=w * x + b
y
# Out:
# array([1.85910406, 2.75141764, 3.64373122, 4.53604479])

# %%
X_new=int( input("please enter new value"))


y = w *  X_new +b
y
# Out:
# np.float64(5.428358370441118)
