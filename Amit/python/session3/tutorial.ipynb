# %%
def user_info(x,y):
    """
    param_1: take first num frm user 
    type :param_1:int
    param_2 :take second num from user

    type_param_2:int 
    return :sum two num 
    type_return :int 
    
    """
    return f"num_1 is {x}, num_2 is {y}, sum = {x+y}"

# %%
user_info(2, 5)
# Out:
# 'num_1 is 2, num_2 is 5, sum = 7'

# %%
def user_info(x,y):
    """
    param_1: take first num frm user 
    type :param_1:int
    param_2 :take second num from user

    type_param_2:int 
    return :sum two num 
    type_return :int 
    
    """
    return f"num_1 is {x}, num_2 is {y}, sub = {x-y}"

# %%
user_info(2, 5)
# Out:
# 'num_1 is 2, num_2 is 5, sub = -3'

# %%
def user_info(x,y):
    """
    param_1: take first num frm user 
    type :param_1:int
    param_2 :take second num from user

    type_param_2:int 
    return :sum two num 
    type_return :int 
    
    """
    return f"num_1 is {x}, num_2 is {y}, multi = {x*y}"

# %%
user_info(2, 5)
# Out:
# 'num_1 is 2, num_2 is 5, multi = 10'

# %%
def get_info(name = "mazen",age=19 ):
    return f"my name is {name} and my age {age}"

# %%
get_info(name ="mazen",age =19)
# Out:
# 'my name is mazen and my age 19'

# %%
def std_info(name,age):
    re

# %%
def function_1(*name):
    print ( name)
    print (type(name))
    function_1 ("hello","python","amit",2,2.5,True)

# %%
def fun_1(**name):
    print(name)
    print(type(name))
    fun_1 (key=10.5,key2=2 , key3= "mlops",key4= "python")

# %%
fun1 =lambda x:x+10
type(fun1)
fun1(10)
# Out:
# 20

# %%
def info():
    return f"hello"

# %%
info
# Out:
# <function __main__.info()>

# %%
def isPrime(num):
    for i in range (2,num):
        if num%i==0:
            return False
    return True
isPrime(20)
# Out:
# False

# %%
def dividors(num1,num2):
    min=min(num1,num2)
    common_dividors=[]
    for i in range (1,mn+1):
        if num1 % i ==0 and num2 %i==0:
            common_dividors.append(i)
    return common_dividors

# %%
eveen=[]
def even_fun(num):
    for i in range (num):
        if i % 2==0:
            print (eveen.append(num))
    return eveen
print(even_fun(3))
# Out:
# None
# None
# [3, 3]

# %%
str1= input()
str2= input()
longest_str=""
for i in range (len(str1)):
    for j in range (i, len(str1)):
       sub_str = str[i:j+1]
       print (sub_str)
       if sub_str in str2:
        if len (sub_str)>len (longest_str):
           longest_str=sub_str
longest_str
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 str1= input()
#       2 str2= input()
#       3 longest_str=""
#
# File c:\Users\asus\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File c:\Users\asus\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# ...
